# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

DATADIR_TRAIN = "./dataset/training_set"
DATADIR_TEST = "./dataset/test_set"
IMG_SIZE = 299
categories = ["cats", "dogs"]
training_data = []
test_data = []
def create_training_data():
    for category in categories:
        path = os.path.join(DATADIR_TRAIN, category)
        class_num = categories.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img))
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                training_data.append([new_array, class_num])
    #             plt.imshow(new_array, cmap = "gray")
    #             plt.show()
            except Exception as e:
                pass
def create_test_data():
    for category in categories:
        path = os.path.join(DATADIR_TEST, category)
        class_num = categories.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img))
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                test_data.append([new_array, class_num])
    #             plt.imshow(new_array, cmap = "gray")
    #             plt.show()
            except Exception as e:
                pass            
create_training_data()
create_test_data()

print(len(training_data))
print(len(test_data))
# Out:
# 8000
# 2000

# %%
import random

random.shuffle(training_data)
random.shuffle(test_data)

# %%
X_train = []
y_train = []
X_test = []
y_test = []
# def reshape(data):
#     return(np.array(data).reshape(-1, 784))

# %%
for features, label in training_data:
    X_train.append(features)
    y_train.append(label)
X_train = np.array(X_train)
y_train = np.array(y_train)
for features, label in test_data:
    X_test.append(features)
    y_test.append(label)
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
# from keras.preprocessing.image import ImageDataGenerator
# datagen = ImageDataGenerator(
#            rotation_range=40,
#            width_shift_range=0.2,
#            height_shift_range=0.2,
#            zoom_range=0.2,
#            horizontal_flip=True,
#            brightness_range=(1, 1.5),
#            fill_mode='nearest')
# batches = 0
# new_x = []
# new_y = []
# for x, y in datagen.flow(np.reshape(X_train, (-1, IMG_SIZE, IMG_SIZE, 3)), y_train, batch_size=1, shuffle = False):
#     batches+=1
# #     plt.imshow(np.reshape((x[0]).astype(int), (IMG_SIZE, IMG_SIZE, 3)), cmap = "gray")
# #     plt.show()
# #     print(y)

#     new_x.append(np.reshape(x, (IMG_SIZE, IMG_SIZE, 3)))
#     new_y.append(y[0])
#     if batches > 4 * len(X_train):
#         break

# %%
# new_x = np.array(new_x)
# new_y = np.array(new_y)
# new_y.shape

# %%
# X_train = np.append(X_train, new_x, axis=0)
# y_train = np.append(y_train, new_y, axis=0)

# %%
X_train = X_train[0:2000]

# %%
X_train = X_train/255
X_test = X_test/255

# %%
import pickle 
pickle_out = open("X_train.pickle", "wb")
pickle.dump(X_train, pickle_out)
pickle_out.close()

pickle_out = open("y_train.pickle", "wb")
pickle.dump(y_train, pickle_out)
pickle_out.close()

pickle_out = open("X_test.pickle", "wb")
pickle.dump(X_test, pickle_out)
pickle_out.close()

pickle_out = open("y_test.pickle", "wb")
pickle.dump(y_test, pickle_out)
pickle_out.close()

# %%
X_train
# Out:
# array([[[[0.52941176, 0.82352941, 0.54509804],
#          [0.60392157, 0.88627451, 0.61960784],
#          [0.56078431, 0.84313725, 0.58039216],
#          ...,
#          [0.32156863, 0.57254902, 0.34509804],
#          [0.45882353, 0.70196078, 0.47843137],
#          [0.56078431, 0.8       , 0.58039216]],
#
#         [[0.47058824, 0.75686275, 0.48235294],
#          [0.45882353, 0.74117647, 0.47058824],
#          [0.41568627, 0.69411765, 0.43529412],
#          ...,
#          [0.15686275, 0.40784314, 0.20392157],
#          [0.32941176, 0.57254902, 0.37254902],
#          [0.52941176, 0.77647059, 0.56862745]],
#
#         [[0.49411765, 0.78039216, 0.50588235],
#          [0.51764706, 0.8       , 0.52941176],
#          [0.51372549, 0.79215686, 0.53333333],
#          ...,
#          [0.23137255, 0.48627451, 0.28627451],
#          [0.26666667, 0.51764706, 0.32156863],
#          [0.34901961, 0.59215686, 0.4       ]],
#
#         ...,
#
# ...
